# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pokemon = pd.read_csv('/kaggle/input/pokemon/pokemon.csv')
pokemon = pokemon.reindex(sorted(pokemon.columns), axis=1)
pokemon.head()

# %%
#sns.pairplot(data = pokemon,hue = "Legendary")

# %%
pokemon.info()

# %%
pokemon['name']

# %%
pokemon["type1"].unique()

# %%
pokemon.describe()

# %%
#pokemon_typings = pokemon[[]]

#pull gen1 to see dragon effectiveness

# %%
pokemon.isnull().sum()

# %%
unique_pokemon_abilities = pokemon['abilities'].value_counts()
print(unique_pokemon_abilities)

#The most common pokemon ability is Levitate, with a value counts of 29

# %%
legendaries = pokemon['is_legendary'].value_counts()
print(legendaries)

70/731
#There are 70 legendary pokemon in our dataset of 801

# %%
different_generations = pokemon['generation'].value_counts()
print(different_generations)

#The largest generation of pokemon is generation 5, with a value counts of 156. Generation 6/7 are <100.

# %% [markdown]
# ****The largest generation of pokemon is generation 5, with a value counts of 156. Generation 6/7 are <100.****

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
pokemon.columns

# %%
pokemon_pairplot = pokemon[['attack','defense','sp_attack','sp_defense','hp','speed','capture_rate']]
pokemon_pairplot

# %%
sns.set(rc={'figure.figsize':(20,16)})

# %%
sns.pairplot(pokemon_pairplot)

# %%
sns.violinplot(x='type1',y='attack',data=pokemon,palette=pkmn_type_colors)

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.violinplot(x='type1',y='defense',data=pokemon,palette=pkmn_type_colors)

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.violinplot(x='type1',y='sp_attack',data=pokemon,palette=pkmn_type_colors)

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.violinplot(x='type1',y='sp_defense',data=pokemon,palette=pkmn_type_colors)

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.violinplot(x='type1',y='hp',data=pokemon,palette=pkmn_type_colors)

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.violinplot(x='type1',y='speed',data=pokemon,palette=pkmn_type_colors)

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.violinplot(x='type1',y='base_total',data=pokemon,palette=pkmn_type_colors)

# %%
pokemon.columns

# %%
gen1 = pokemon.loc[pokemon.generation==1,:]
sns.set(rc={'figure.figsize':(12,8)})
sns.scatterplot('attack','defense',data=gen1)

# %%
gen1_typings= gen1.iloc[:, : 18]
gen1_typings = gen1_typings.drop(['against_fairy'], axis=1)
gen1_typings.describe()

# %%
gen2 = pokemon.loc[pokemon.generation==2,:]
gen2_typings= gen2.iloc[:, : 18]
gen2_typings = gen2_typings.drop(['against_fairy'], axis=1)
gen2_typings.describe()

# %%
gen3 = pokemon.loc[pokemon.generation==3,:]
gen3_typings= gen3.iloc[:, : 18]
gen3_typings = gen3_typings.drop(['against_fairy'], axis=1)
gen3_typings.describe()

# %%
gen4 = pokemon.loc[pokemon.generation==4,:]
gen4_typings= gen4.iloc[:, : 18]
gen4_typings = gen4_typings.drop(['against_fairy'], axis=1)
gen4_typings.describe()

# %%
gen5 = pokemon.loc[pokemon.generation==5,:]
gen5_typings= gen5.iloc[:, : 18]
gen5_typings = gen5_typings.drop(['against_fairy'], axis=1)
gen5_typings.describe()

# %%
gen6 = pokemon.loc[pokemon.generation==6,:]
gen6_typings= gen2.iloc[:, : 18]
gen6_typings.describe()

# %%
gen7 = pokemon.loc[pokemon.generation==7,:]
gen7_typings= gen7.iloc[:, : 18]
gen7_typings.describe()

# %%
plt.figure(figsize = (16,10))
plt.scatter('attack', 'defense', data=pokemon[pokemon.is_legendary==1], marker = 'o', c = 'blue')
plt.scatter('attack', 'defense', data=pokemon[pokemon.is_legendary==0], marker = 'x', c = 'red')
plt.legend(('No', 'Yes'), title='Is the pokemon a legendary?')
plt.title('Is the Pokemon Legendary?', fontsize=16)
plt.xlabel('Attack', fontsize=12)
plt.ylabel('Defense', fontsize=12)
plt.show()

# %%
grass = pokemon[pokemon.type1 == 'grass']
grass.plot.scatter('height_m', 'weight_kg', figsize=(10,6))
plt.grid(True) # add gridlines
plt.show()

# %%
grass.plot.scatter('height_m', 'weight_kg', figsize=(12,8))
plt.grid(True)
for index, row in grass.nlargest(4, 'height_m').iterrows():
    plt.annotate(row['name'], # text to show
                 xy = (row['height_m'], row['weight_kg']), # the point to annotate 
                 xytext = (row['height_m']+0.1, row['weight_kg']), # where to show the text
                 fontsize=12)
plt.xlim(0, ) # x-axis has minimum 0
plt.ylim(0, ) # y-axis has minimum 0
plt.show()

# %%
sns.lmplot(x = "defense", y = "attack", data=pokemon, height = 7, aspect = 9/7, hue = 'is_legendary')

# %%
plt.figure(figsize=(12,8))
sns.set()
plt.title('Pokemon Typing Graph')
graph1 = sns.countplot(x = 'type1',data=pokemon)
graph1.set_xticklabels(graph1.get_xticklabels(), rotation=45)
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.distplot(pokemon['base_total'],color='r')

# %%
sns.set()
plt.figure(figsize=(14,8))
k = sns.boxplot(x='type1',y = 'base_total', data = pokemon)
k.set_xticklabels(k.get_xticklabels(), rotation=45)
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.set()
plt.title('Count of pokemon by generations')
gen = sns.countplot(x = 'generation',data=pokemon)
gen.set_xticklabels(gen.get_xticklabels(), rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,8))
correlational_data = pokemon[['sp_attack','attack','defense','sp_defense','speed','hp']]
sns.heatmap(correlational_data.corr(),square=True,robust=True,annot=True,cmap='jet')

# %%
pokemon.columns

# %%
def legendary_conversion(x):
    if x == True:
        return 0
    if x == False:
        return 1
    

pokemon['is_legendary'] = pokemon['is_legendary'].apply(lambda x: legendary_conversion(x))

pokemon['is_legendary'].value_counts()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
capture_rate = pokemon['capture_rate']
generation = pokemon['generation']

# %%
pokemon_model=DecisionTreeRegressor(random_state=1)
pokemon_model.fit(correlational_data,generation)

# %%
x2 = pokemon[['generation','sp_attack','attack','defense','sp_defense','speed']]
print("Making Generation predictions for the following 5 Pokemon:")
print(correlational_data.head())
print("The predictions are")
print(pokemon_model.predict(correlational_data.head()))
print(x2['generation'].head())

# %%
pokemon.columns

# %%
pokemon.capture_rate.unique()
pokemon.loc[pokemon['capture_rate'] == '30 (Meteorite)255 (Core)']
pokemon_updated = pokemon.drop(index=773)


pokemon_updated.loc[pokemon_updated['capture_rate'] == '30 (Meteorite)255 (Core)']

# %%
pokemon['capture_rate'].describe()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

# %%
x = pokemon_updated[['base_total','capture_rate']]
y = pokemon_updated['is_legendary']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)


log = LogisticRegression()
log.fit(X_train,y_train)
predictions = log.predict(X_test)


print(confusion_matrix(y_test,predictions))
print("\n")
print(classification_report(y_test,predictions))

# %%
pokemon.columns

# %%
x = pokemon_updated[['experience_growth','capture_rate']]
y = pokemon_updated['is_legendary']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)


log = LogisticRegression()
log.fit(X_train,y_train)
predictions = log.predict(X_test)


print(confusion_matrix(y_test,predictions))
print("\n")
print(classification_report(y_test,predictions))

# %%
x = pokemon_updated[['attack','generation']]
y = pokemon_updated['is_legendary']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)


log = LogisticRegression()
log.fit(X_train,y_train)
predictions = log.predict(X_test)


print(confusion_matrix(y_test,predictions))
print("\n")
print(classification_report(y_test,predictions))

# %%
x = pokemon_updated[['defense','generation']]
y = pokemon_updated['is_legendary']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)


log = LogisticRegression()
log.fit(X_train,y_train)
predictions = log.predict(X_test)


print(confusion_matrix(y_test,predictions))
print("\n")
print(classification_report(y_test,predictions))

# %%
x = pokemon_updated[['sp_attack','generation']]
y = pokemon_updated['is_legendary']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)


log = LogisticRegression()
log.fit(X_train,y_train)
predictions = log.predict(X_test)


print(confusion_matrix(y_test,predictions))
print("\n")
print(classification_report(y_test,predictions))

# %%
x = pokemon_updated[['sp_defense','generation']]
y = pokemon_updated['is_legendary']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)


log = LogisticRegression()
log.fit(X_train,y_train)
predictions = log.predict(X_test)


print(confusion_matrix(y_test,predictions))
print("\n")
print(classification_report(y_test,predictions))

# %%
pokemon.dtypes
